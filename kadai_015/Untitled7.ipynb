# %%
class Human:
  def __init__(self,name, age):
    self.name = name
    self.age = age

  def printinfo(self):
    print(f"Name/ {self.name}　Age/ {self.age}")

hito = Human("samurai", 20)

hito.printinfo()
# Out:
# Name/ samurai　Age/ 20
